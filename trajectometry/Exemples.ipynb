# %%
from importlib import reload
import repartition
import transition
reload(repartition)
reload(transition)
import matplotlib.pyplot as plt

# %% [markdown]
# # Répartition des habitants d'un secteur
# On voit leur localisation ainsi que la proportion restant dans leur secteur.

# %%
repartition.plot(101)
# Out:
# Chargement du secteur 101 ...

# %%
repartition.plot(301)
# Out:
# Chargement du secteur 301 ...

# %% [markdown]
# # Matrice de 'transition'
# On observe la manière dont les personnes se déplacent entre deux instants.

# %%
a,(b,c) = transition.passage(101, 2030, 1800, verbose=True)
# Out:
# 1800 -> 1815
# Chargement du secteur 101 ...
# 1815 -> 1830
# 1830 -> 1845
# 1845 -> 1900
# 1900 -> 1915
# 1915 -> 1930
# 1930 -> 1945
# 1945 -> 2000
# 2000 -> 2015
# 2015 -> 2030
